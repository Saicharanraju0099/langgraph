# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def function1(input1):
    return input1 + " this is from first function"

# %%
def function2(input2):
    return input2 + " charan this is from second function"

# %%
def function3(input3):
    pass

# %%
function1("sai")
# Out:
# 'sai this is from first function'

# %%
function2("charan")
# Out:
# 'charan charan this is from second function'

# %%
from langgraph.graph import Graph

# %%
workflow1=Graph()

# %%
workflow1.add_node("fun1",function1) # creating nodes in workflow that is function 1 as node 1

# %%
workflow1.add_node("fun2",function2) # creating nodes in workflow that is function 2 as node 2

# %%
workflow1.add_edge("fun1","fun2")

# %%
workflow1.set_entry_point("fun1")

# %%
workflow1.set_finish_point("fun2")

# %%
app = workflow1.compile()

# %%
app.get_graph()
# Out:
# Graph(nodes={'fun1': Node(id='fun1', name='fun1', data=fun1(tags=None, recurse=True, explode_args=False, func_accepts_config=False, func_accepts={}), metadata=None), 'fun2': Node(id='fun2', name='fun2', data=fun2(tags=None, recurse=True, explode_args=False, func_accepts_config=False, func_accepts={}), metadata=None), '__start__': Node(id='__start__', name='__start__', data=None, metadata=None), '__end__': Node(id='__end__', name='__end__', data=None, metadata=None)}, edges=[Edge(source='__start__', target='fun1', data=None, conditional=False), Edge(source='fun1', target='fun2', data=None, conditional=False), Edge(source='fun2', target='__end__', data=None, conditional=False)])

# %% [markdown]
# Displaying simple graph

# %%
from IPython.display import Image,display

# %%
display(Image(app.get_graph().draw_mermaid_png()))

# %%
app.invoke("hi iam sai")
# Out:
# 'hi iam sai this is from first function charan this is from second function'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# creating a second workflow

# %%
import os
os.environ["GOOGLE_API_KEY"] = "YOUR_GOOGLE_API_KEY"

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model=ChatGoogleGenerativeAI(model='gemini-1.5-flash')

# %%
model.invoke("hi who are you").content
# Out:
# "I am a large language model, trained by Google.  I'm an AI and don't have a name or personal identity.  My purpose is to help users by providing information, generating text, and answering questions to the best of my ability."

# %%
def llm(input):
   from langchain_google_genai import ChatGoogleGenerativeAI
   model=ChatGoogleGenerativeAI(model='gemini-1.5-flash')
   output=model.invoke(input)
   return output.content

# %%
def tokencounter(input):
    token = input.split()
    token_number = len(token)
    return f"total number of tokens generated in answer is {token_number}"

# %%
workflow2=Graph()

# %%
workflow2.add_node("myllm", llm)

# %%
workflow2.add_node("llm output token counter",tokencounter)

# %%
workflow2.add_edge("myllm","llm output token counter")

# %%
workflow2.set_entry_point("myllm")

# %%
workflow2.set_finish_point("llm output token counter")

# %%
app=workflow2.compile()

# %%
display(Image(app.get_graph().draw_mermaid_png()))

# %%
app.invoke("can you tell me about india's capital?")
# Out:
# 'total number of tokens generated in answer is 180'

# %%
app.invoke("can you tell me about tata steel?")
# Out:
# 'total number of tokens generated in answer is 377'

# %%
for output in app.stream("can you tell me about tata steel?"):
    for key,value in output.items():
        print(f"here is output from {key}")
        print("_______")
        print(value)
        print("\n")
# Out:
# here is output from myllm
# _______
# Tata Steel is one of the world's leading steel producers, with a history spanning over a century.  Here's a summary of key aspects:
#
# **History and Ownership:**
#
# * Founded in 1907 as Tata Iron and Steel Company (TISCO) in Jamshedpur, India, by Jamsetji Tata.  This marked a significant step in India's industrialization.
# * Remains a part of the Tata Group, a large Indian multinational conglomerate.
#
# **Operations and Products:**
#
# * **Global Presence:**  Tata Steel has a significant presence in India and the UK, with operations and sales across numerous countries.  They have integrated operations, meaning they control much of the process from raw materials to finished products.
# * **Product Range:** Produces a wide range of steel products for various sectors including construction, automotive, energy, and packaging.  This includes flat products (like sheets and coils) and long products (like bars and rails).
# * **Raw Materials:**  Relies on iron ore, coking coal, and other raw materials, some of which are sourced from their own mines and others from external suppliers.
#
# **Key Highlights:**
#
# * **Technological Advancement:**  Constantly invests in research and development to improve its manufacturing processes, product quality, and sustainability.
# * **Sustainability Initiatives:**  Increasingly focused on environmental, social, and governance (ESG) factors, including reducing carbon emissions, responsible sourcing of raw materials, and community development.  They have set ambitious targets for carbon neutrality.
# * **Market Position:**  A major player in both domestic and international steel markets, competing with other global giants.
# * **Financial Performance:**  Like other steel companies, its financial performance is subject to fluctuations in global steel prices and demand.
#
# **Challenges:**
#
# * **Global Competition:** Faces intense competition from other steel producers worldwide.
# * **Raw Material Costs:** Fluctuations in the prices of raw materials significantly impact profitability.
# * **Environmental Regulations:**  Increasingly stringent environmental regulations necessitate investment in cleaner technologies.
# * **Economic Conditions:**  The overall economic climate and demand for steel influence its performance.
#
#
# In short, Tata Steel is a large, globally significant steel producer with a long history and a commitment to modernization and sustainability.  However, it operates in a competitive and volatile market, facing challenges related to costs, environmental concerns, and global economic conditions.
#
#
# here is output from llm output token counter
# _______
# total number of tokens generated in answer is 350
